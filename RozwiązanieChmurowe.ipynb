# %% [markdown]
# <a href="https://colab.research.google.com/github/laptosia-lab/blank-app/blob/main/Rozwi%C4%85zanieChmurowe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google. colab import drive
drive. mount ('/content/drive')

# %%
towary=["sok", "bułka", "zeszyt"]

plik_towary = "/content/drive/MyDrive/Colab Notebooks"

def wczytej_towary():
  if not os.path.exists(plik_towary):
    return []
  with open(plik_towary, "r", encoding="utf-8") as f:
    return [linia.strop() for linia in f.readlines()]

def zapisz_towary(towary):
  with open(plik_towary, "w", encoding="utf-8") as f:
    for towary in towary:
        f.write(towary + "\n")

def pokaz_towary() :
  print(towary)

def dostawa():
  x=input("Podaj nazwę towaru: ")
  towary.append(x)
  zapisz_towary(towary)
  pokaz_towary()

def wydanie():
  y+input("Podaj nazwę wydanego towaru: ")
  if y in towary:
    towary.remove(y)
    zapisz_towary(towary)
  else:
    print("Nie ma takiego towaru na stanie")
  pokaz_towary()

def liczba_towarow():
  print(f"Liczba towarów wynosi: {len(towary) }")

def liczba_okreslonego():
  co=input("Jaki towar?")
  liczba = sum(1 for towar in towary if towar == co)
  print(f"Towary {co} jest {liczba} sztuk")

def menu():
  pokaz_towary()
  while True:
    operacja=input("Podaj: D - dostawa, W - wydanie, S - koniec, R - liczba towarów, L - liczba określonych towarów: ").upper()
    match operacja:
      case "D": dostawa()
      case "W": wydanie()
      case "R": liczba_towarow()
      case "L": liczba_okreslonego()
      case "S": break
      case _: print("Nieznana operacja. Spróbuj ponownie.")

menu()
# Out:
# ['sok', 'bułka', 'zeszyt']
# Podaj: D - dostawa, W - wydanie, S - koniec, R - liczba towarów, L - liczba określonych towarów: W
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3614429196.py in <cell line: 0>()
#      52       case _: print("Nieznana operacja. Spróbuj ponownie.")
#      53
# ---> 54 menu()
#
# /tmp/ipython-input-3614429196.py in menu()
#      46     match operacja:
#      47       case "D": dostawa()
# ---> 48       case "W": wydanie()
#      49       case "R": liczba_towarow()
#      50       case "L": liczba_okreslonego()
#
# /tmp/ipython-input-3614429196.py in wydanie()
#      24
#      25 def wydanie():
# ---> 26   y+input("Podaj nazwę wydanego towaru: ")
#      27   if y in towary:
#      28     towary.remove(y)
#
# NameError: name 'y' is not defined

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect("baza_danych")
cursor = conn.cursor()

cursor.execute('''CREATE TABLE IF NOT EXISTS ''')
conn.comit()
conn.close()
